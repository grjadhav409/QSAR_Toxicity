# %%
import os
os.getcwd()
# Out:
# '/Users/ganeshjadhav/Desktop/sensor3'

# %%
from datetime import datetime

datetime.now().strftime('%d%m%Y__%H%M%S')
# Out:
# '22012023__195121'

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 1, 22, 19, 50, 47, 903105)

# %%
import pymongo

# %%
mongo_db_url= os.getenv("MONGO_DB_URL")

# %%
mongo_db_url
# Out:
# 'mongodb+srv://grjadhav:Pass123@cluster0.4fkiw4h.mongodb.net/?retryWrites=true&w=majority'

# %%
import sensor.utils as ut

# %%
import pandas as pd

# %%
import pymongo

# %%
mongo_client = pymongo.MongoClient("mongodb+srv://grjadhav:Pass123@cluster0.4fkiw4h.mongodb.net/?retryWrites=true&w=majority")
# Out:
# ---------------------------------------------------------------------------
# LifetimeTimeout                           Traceback (most recent call last)
# File ~/pytorch-test/env/lib/python3.8/site-packages/pymongo/srv_resolver.py:89, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#      88 try:
# ---> 89     results = _resolve(
#      90         "_" + self.__srv + "._tcp." + self.__fqdn, "SRV", lifetime=self.__connect_timeout
#      91     )
#      92 except Exception as exc:
#
# File ~/pytorch-test/env/lib/python3.8/site-packages/pymongo/srv_resolver.py:43, in _resolve(*args, **kwargs)
#      41 if hasattr(resolver, "resolve"):
#      42     # dnspython >= 2
# ---> 43     return resolver.resolve(*args, **kwargs)
#      44 # dnspython 1.X
#
# File ~/pytorch-test/env/lib/python3.8/site-packages/dns/resolver.py:1368, in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
# ...

# %%
df = pd.DataFrame(list(mongo_client["aps"]["sensor"].find()))
